# %%
# !pip freeze
# Out:
# -illow @ file:///C:/ci/pillow_1603823068645/work
# absl-py==0.11.0
# adal==1.2.5
# aiohttp==3.7.3
# alabaster==0.7.12
# altair==4.1.0
# anaconda-client==1.7.2
# anaconda-navigator==1.10.0
# anaconda-project==0.8.3
# ansiwrap==0.8.4
# WARNING: Could not generate requirement for distribution -olcore 5.7.2 (c:\anaconda\lib\site-packages): Parse error at "'-olcore='": Expected W:(abcd...)
# appdirs==1.4.4
# argcomplete==1.10.0
# argh==0.26.2
# argon2-cffi @ file:///C:/ci/argon2-cffi_1596828585465/work
# args==0.1.0
# asgiref==3.3.1
# asn1crypto @ file:///tmp/build/80754af9/asn1crypto_1596577642040/work
# asteval==0.9.21
# astroid @ file:///C:/ci/astroid_1592487315634/work
# astropy==4.0.2
# astunparse==1.6.3
# async-generator==1.10
# async-timeout==3.0.1
# atomicwrites==1.4.0
# attrs @ file:///tmp/build/80754af9/attrs_1604765588209/work
# autobahn==21.2.1
# Automat==20.2.0
# autopep8 @ file:///tmp/build/80754af9/autopep8_1596578164842/work
# awscli==1.18.195
# azure==2.0.0rc6
# ...
